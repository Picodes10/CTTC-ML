# %%
# ML

# %% [raw]
# ML is a branch of Ai where the machine try to learn from the data and the given algorithm

# %% [raw]
# 1. Supervised
# 2. unsupervised
# 3. semisupervised
# 4. Reinforcement learning

# %% [raw]
# Supervised is divided into 2 parts:
# 1. Regression (on the basis of continuous output)
# 2. Classification (categorical output)

# %% [raw]
# Steps of doing ML
# 1. data reading
# 2. data analysis
# 3. data cleaning
# 4. data visualization
# 5. data preprocessing (1. Encoding
#                        2. Input and output creation
#                        3. Train & test split
#                        4. standardization
#                        5. model/algorithm selection
#                        6. model training
#                        7. model testing (accuracy)
#                        8. model prediction (future prediction))

# %% [raw]
# # Regression algorithm
# 1. Simple Linear regression (1_input and 1_output)
# 2. multiple Linear regression (more_than-1_input and 1_output)
# 3. K nearst regressor

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
adv = pd.read_csv(r"C:\Users\DELL\Documents\SushreeM\advertisment data\Advertising Budget and Sales.csv")
adv
# Out:
#      Unnamed: 0  TV Ad Budget ($)  Radio Ad Budget ($)  \
# 0             1             230.1                 37.8
# 1             2              44.5                 39.3
# 2             3              17.2                 45.9
# 3             4             151.5                 41.3
# 4             5             180.8                 10.8
# ..          ...               ...                  ...
# 195         196              38.2                  3.7
# 196         197              94.2                  4.9
# 197         198             177.0                  9.3
# 198         199             283.6                 42.0
# 199         200             232.1                  8.6
#
#      Newspaper Ad Budget ($)  Sales ($)
# 0                       69.2       22.1
# 1                       45.1       10.4
# 2                       69.3        9.3
# 3                       58.5       18.5
# 4                       58.4       12.9
# ..                       ...        ...
# ...

# %%
adv = adv.set_index('Unnamed: 0')
adv
# Out:
#             TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)  \
# Unnamed: 0
# 1                      230.1                 37.8                     69.2
# 2                       44.5                 39.3                     45.1
# 3                       17.2                 45.9                     69.3
# 4                      151.5                 41.3                     58.5
# 5                      180.8                 10.8                     58.4
# ...                      ...                  ...                      ...
# 196                     38.2                  3.7                     13.8
# 197                     94.2                  4.9                      8.1
# 198                    177.0                  9.3                      6.4
# 199                    283.6                 42.0                     66.2
# 200                    232.1                  8.6                      8.7
#
#             Sales ($)
# Unnamed: 0
# ...

# %%
adv.columns = ['TV','Radio','Budget','Sales']
adv
# Out:
#                TV  Radio  Budget  Sales
# Unnamed: 0
# 1           230.1   37.8    69.2   22.1
# 2            44.5   39.3    45.1   10.4
# 3            17.2   45.9    69.3    9.3
# 4           151.5   41.3    58.5   18.5
# 5           180.8   10.8    58.4   12.9
# ...           ...    ...     ...    ...
# 196          38.2    3.7    13.8    7.6
# 197          94.2    4.9     8.1    9.7
# 198         177.0    9.3     6.4   12.8
# 199         283.6   42.0    66.2   25.5
# 200         232.1    8.6     8.7   13.4
#
# [200 rows x 4 columns]

# %%
adv.tail()
# Out:
#                TV  Radio  Budget  Sales
# Unnamed: 0
# 196          38.2    3.7    13.8    7.6
# 197          94.2    4.9     8.1    9.7
# 198         177.0    9.3     6.4   12.8
# 199         283.6   42.0    66.2   25.5
# 200         232.1    8.6     8.7   13.4

# %%
adv.head()
# Out:
#                TV  Radio  Budget  Sales
# Unnamed: 0
# 1           230.1   37.8    69.2   22.1
# 2            44.5   39.3    45.1   10.4
# 3            17.2   45.9    69.3    9.3
# 4           151.5   41.3    58.5   18.5
# 5           180.8   10.8    58.4   12.9

# %%
adv.isnull().sum()
# Out:
# TV        0
# Radio     0
# Budget    0
# Sales     0
# dtype: int64

# %%
adv.describe(include='all')
# Out:
#                TV       Radio      Budget       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
plt.plot(adv.TV)
plt.show()

# %%
plt.plot(adv.Sales)
plt.show()

# %%
plt.plot(adv.Budget,adv.Sales)
plt.title('LINE PLOT')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)
plt.show()

# %%
plt.bar(adv.TV,adv.Sales,color='cyan',label='col_cyan',width=0.5)
plt.bar(adv.Budget,adv.Radio,color='grey',label='col_grey',width=0.5)
plt.legend()
plt.show()

# %%
plt.scatter(adv.Budget,adv.Sales,marker='H',color='orange',s=30)
plt.show()

# %%
ad = ['TV','Radio','Budget']
freq = [46,21,33]

# %%
plt.pie(freq,labels=ad,autopct='%1.1f%%')
plt.show()

# %%
sns.kdeplot(adv.Sales)
plt.show()

# %%
sns.displot(adv.Sales)
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(adv.Sales)
plt.show()

# %%
sns.countplot(x=adv.Budget)
plt.show()

# %%
sns.boxplot(x=adv.TV,y=adv.Sales)
plt.show()

# %%
sns.violinplot(x=adv.TV,y=adv.Sales)
plt.show()

# %%
sns.boxenplot(x=adv.TV,y=adv.Sales)
plt.show()

# %%
sns.pairplot(adv)
plt.show()

# %%
cor = adv.corr()
cor
# Out:
#               TV     Radio    Budget     Sales
# TV      1.000000  0.054809  0.056648  0.782224
# Radio   0.054809  1.000000  0.354104  0.576223
# Budget  0.056648  0.354104  1.000000  0.228299
# Sales   0.782224  0.576223  0.228299  1.000000

# %%
plt.figure(figsize=(6,6))
sns.heatmap(cor,annot=True)
plt.show()

# %%
# INPUT and OUTPUT
ip = adv.drop(['Sales'],axis=1)
op = adv.Sales

# %%
ip
# Out:
#                TV  Radio  Budget
# Unnamed: 0
# 1           230.1   37.8    69.2
# 2            44.5   39.3    45.1
# 3            17.2   45.9    69.3
# 4           151.5   41.3    58.5
# 5           180.8   10.8    58.4
# ...           ...    ...     ...
# 196          38.2    3.7    13.8
# 197          94.2    4.9     8.1
# 198         177.0    9.3     6.4
# 199         283.6   42.0    66.2
# 200         232.1    8.6     8.7
#
# [200 rows x 3 columns]

# %%
op
# Out:
# Unnamed: 0
# 1      22.1
# 2      10.4
# 3       9.3
# 4      18.5
# 5      12.9
#        ...
# 196     7.6
# 197     9.7
# 198    12.8
# 199    25.5
# 200    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
# train ticket split
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(ip,op,train_size=0.8,random_state=3)

# %%
xtrain
# Out:
#                TV  Radio  Budget
# Unnamed: 0
# 157          93.9   43.5    50.5
# 116          75.1   35.0    52.7
# 156           4.1   11.6     5.7
# 16          195.4   47.7    52.9
# 62          261.3   42.7    54.7
# ...           ...    ...     ...
# 1           230.1   37.8    69.2
# 185         253.8   21.3    30.0
# 132         265.2    2.9    43.0
# 153         197.6   23.3    14.2
# 107          25.0   11.0    29.7
#
# [160 rows x 3 columns]

# %%
# standardization

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
xtrain1 = sc.fit_transform(xtrain)
xtest1 = sc.fit_transform(xtest)

# %%
xtrain1
# Out:
# array([[-0.62579748,  1.39757261,  0.91683005],
#        [-0.83959224,  0.81633695,  1.01775389],
#        [-1.64700866, -0.78377065, -1.13834642],
#        [ 0.52846684,  1.68477142,  1.02692879],
#        [ 1.27788574,  1.34286808,  1.10950284],
#        [ 1.45528991,  1.76682822,  0.51772212],
#        [-0.08676173,  0.25561548,  0.71956981],
#        [-1.68567367,  1.13088801, -1.00072299],
#        [ 0.90260768, -0.42135312, -0.19791969],
#        [ 0.25440014,  1.13772608,  0.32963677],
#        [-0.40972829, -0.38716279,  0.3709238 ],
#        [ 0.44317637, -0.40083892, -0.57867783],
#        [-0.44498169,  1.69160948,  0.95811707],
#        [-1.59810879,  0.28296775, -1.30349452],
#        [ 1.21079057,  0.26245355, -1.14752131],
#        [-1.60493203,  1.08302155,  0.92141749],
#        [ 1.50646419,  1.13088801,  1.15996476],
#        [ 1.6372429 ,  0.35818648,  0.58194638],
#        [ 1.45301549, -1.41971086, -0.31260587],
#        [ 0.4488624 , -0.33929632, -0.22544437],
# ...

# %%
# model_selection

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
# model_training
lr.fit(xtrain1,ytrain)
# Out:
# LinearRegression()

# %%
# model_testing

# %%
ypred = lr.predict(xtest1)
ypred
# Out:
# array([17.03923419,  9.35843242, 19.8387182 , 13.38251551,  7.04580672,
#         9.92748237, 25.22794062,  8.88102429, 18.31645691, 14.9764097 ,
#        12.91223966, 13.79018597, 16.95325943, 11.62342445, 12.59722368,
#        12.54886943, 16.60480496, 17.67801321, 17.63027046, 22.25515083,
#        18.99285405,  8.93831048,  9.81419781, 11.15278008,  6.35900282,
#        13.2075929 , 22.61343755, 14.68798883, 24.56140347, 11.21779547,
#        16.81910678, 22.36463878,  9.45987027,  7.68126658,  9.33605375,
#         8.21353266, 13.90993578,  9.55016898, 12.29055447, 10.14204546])

# %%
ytest
# Out:
# Unnamed: 0
# 41     16.6
# 52     10.7
# 140    20.7
# 198    12.8
# 171     8.4
# 83     11.3
# 184    26.2
# 47     10.6
# 71     18.3
# 101    11.7
# 180    12.6
# 84     13.6
# 26     12.0
# 191    10.8
# 160    12.9
# 174    11.7
# 96     16.9
# 4      18.5
# 42     17.1
# 59     23.8
# 15     19.0
# 144    10.4
# 13      9.2
# 7      11.8
# 183     8.7
# 162    13.3
# 129    24.7
# 123    11.6
# 102    23.8
# 87     12.0
# 65     18.0
# 48     23.2
# 159     7.3
# 35      9.5
# 39     10.1
# 197     9.7
# 5      12.9
# 73      8.8
# 68     13.4
# 146    10.3
# Name: Sales, dtype: float64

# %%
from sklearn.metrics import r2_score , mean_squared_error
print('accuracy =',r2_score(ypred,ytest),'mse =',mean_squared_error(ypred,ytest))
# Out:
# accuracy = 0.9082999968719611 mse = 2.2553779718378637
