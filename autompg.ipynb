# %%
import pandas as pd
import numpy as np

# %%
auto = pd.read_csv(r"C:\Users\DELL\Downloads\archive\auto-mpg.csv")
auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
auto.columns = ['mpg','cylinder','dis','horsepower','weight','acceleration','model_year','origin','car_name']
auto
# Out:
#       mpg  cylinder    dis horsepower  weight  acceleration  model_year  \
# 0    18.0         8  307.0        130    3504          12.0          70
# 1    15.0         8  350.0        165    3693          11.5          70
# 2    18.0         8  318.0        150    3436          11.0          70
# 3    16.0         8  304.0        150    3433          12.0          70
# 4    17.0         8  302.0        140    3449          10.5          70
# ..    ...       ...    ...        ...     ...           ...         ...
# 393  27.0         4  140.0         86    2790          15.6          82
# 394  44.0         4   97.0         52    2130          24.6          82
# 395  32.0         4  135.0         84    2295          11.6          82
# 396  28.0         4  120.0         79    2625          18.6          82
# 397  31.0         4  119.0         82    2720          19.4          82
#
#      origin                   car_name
# 0         1  chevrolet chevelle malibu
# ...

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinder      398 non-null    int64
#  2   dis           398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car_name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
auto.head()
# Out:
#     mpg  cylinder    dis horsepower  weight  acceleration  model_year  origin  \
# 0  18.0         8  307.0        130    3504          12.0          70       1
# 1  15.0         8  350.0        165    3693          11.5          70       1
# 2  18.0         8  318.0        150    3436          11.0          70       1
# 3  16.0         8  304.0        150    3433          12.0          70       1
# 4  17.0         8  302.0        140    3449          10.5          70       1
#
#                     car_name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
auto.tail()
# Out:
#       mpg  cylinder    dis horsepower  weight  acceleration  model_year  \
# 393  27.0         4  140.0         86    2790          15.6          82
# 394  44.0         4   97.0         52    2130          24.6          82
# 395  32.0         4  135.0         84    2295          11.6          82
# 396  28.0         4  120.0         79    2625          18.6          82
# 397  31.0         4  119.0         82    2720          19.4          82
#
#      origin         car_name
# 393       1  ford mustang gl
# 394       2        vw pickup
# 395       1    dodge rampage
# 396       1      ford ranger
# 397       1       chevy s-10

# %%
auto.describe()
# Out:
#               mpg    cylinder         dis       weight  acceleration  \
# count  398.000000  398.000000  398.000000   398.000000    398.000000
# mean    23.514573    5.454774  193.425879  2970.424623     15.568090
# std      7.815984    1.701004  104.269838   846.841774      2.757689
# min      9.000000    3.000000   68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000  104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000  148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000  262.000000  3608.000000     17.175000
# max     46.600000    8.000000  455.000000  5140.000000     24.800000
#
#        model_year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
auto.isnull().sum()
# Out:
# mpg             0
# cylinder        0
# dis             0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# car_name        0
# dtype: int64

# %%
for i in auto:
    print(i,auto[i].unique())
# Out:
# mpg [18.  15.  16.  17.  14.  24.  22.  21.  27.  26.  25.  10.  11.   9.
#  28.  19.  12.  13.  23.  30.  31.  35.  20.  29.  32.  33.  17.5 15.5
#  14.5 22.5 24.5 18.5 29.5 26.5 16.5 31.5 36.  25.5 33.5 20.5 30.5 21.5
#  43.1 36.1 32.8 39.4 19.9 19.4 20.2 19.2 25.1 20.6 20.8 18.6 18.1 17.7
#  27.5 27.2 30.9 21.1 23.2 23.8 23.9 20.3 21.6 16.2 19.8 22.3 17.6 18.2
#  16.9 31.9 34.1 35.7 27.4 25.4 34.2 34.5 31.8 37.3 28.4 28.8 26.8 41.5
#  38.1 32.1 37.2 26.4 24.3 19.1 34.3 29.8 31.3 37.  32.2 46.6 27.9 40.8
#  44.3 43.4 36.4 44.6 40.9 33.8 32.7 23.7 23.6 32.4 26.6 25.8 23.5 39.1
#  39.  35.1 32.3 37.7 34.7 34.4 29.9 33.7 32.9 31.6 28.1 30.7 24.2 22.4
#  34.  38.  44. ]
# cylinder [8 4 6 3 5]
# dis [307.  350.  318.  304.  302.  429.  454.  440.  455.  390.  383.  340.
#  400.  113.  198.  199.  200.   97.  110.  107.  104.  121.  360.  140.
#   98.  232.  225.  250.  351.  258.  122.  116.   79.   88.   71.   72.
# ...

# %%
qm = 0
for i in auto.horsepower:
    if i == '?':
        qm = qm + 1
qm
# Out:
# 6

# %%
# question marks inside the whole dataset
for i in auto:
    print(i, auto[i]=='?')
# Out:
# mpg 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Name: mpg, Length: 398, dtype: bool
# cylinder 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Name: cylinder, Length: 398, dtype: bool
# dis 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Name: dis, Length: 398, dtype: bool
# horsepower 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Name: horsepower, Length: 398, dtype: bool
# weight 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# ...

# %%
for i in auto:
    print(i, '=', sum(auto[i]=='?'))
# Out:
# mpg = 0
# cylinder = 0
# dis = 0
# horsepower = 6
# weight = 0
# acceleration = 0
# model_year = 0
# origin = 0
# car_name = 0

# %%
# replacing question mark

# %%
auto.horsepower.describe()
# Out:
# count     398
# unique     94
# top       150
# freq       22
# Name: horsepower, dtype: object

# %%
auto.horsepower = auto.horsepower.replace('?','150')

# %%
for i in auto:
    print(i, '=', sum(auto[i]=='?'))
# Out:
# mpg = 0
# cylinder = 0
# dis = 0
# horsepower = 0
# weight = 0
# acceleration = 0
# model_year = 0
# origin = 0
# car_name = 0

# %%
auto.horsepower.unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
# changing it to int
auto.horsepower = auto.horsepower.astype('int64')

# %%
auto.horsepower.dtype
# Out:
# dtype('int64')

# %% [markdown]
# # seaborn

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
sns.kdeplot(auto.horsepower)
plt.show()

# %%
sns.displot(auto.horsepower)
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(auto.horsepower)
plt.show()

# %%
sns.countplot(x=auto.origin)
plt.show()

# %%
sns.boxplot(x=auto.car_name,y=auto.mpg)
plt.show()

# %%
sns.violinplot(x=auto.car_name,y=auto.mpg)
plt.show()

# %%
sns.boxenplot(x=auto.car_name,y=auto.mpg)
plt.show()

# %%
sns.pairplot(auto)
plt.show()

# %%
auto1 = auto.drop(['car_name'],axis=1)
auto1
# Out:
#       mpg  cylinder    dis  horsepower  weight  acceleration  model_year  \
# 0    18.0         8  307.0         130    3504          12.0          70
# 1    15.0         8  350.0         165    3693          11.5          70
# 2    18.0         8  318.0         150    3436          11.0          70
# 3    16.0         8  304.0         150    3433          12.0          70
# 4    17.0         8  302.0         140    3449          10.5          70
# ..    ...       ...    ...         ...     ...           ...         ...
# 393  27.0         4  140.0          86    2790          15.6          82
# 394  44.0         4   97.0          52    2130          24.6          82
# 395  32.0         4  135.0          84    2295          11.6          82
# 396  28.0         4  120.0          79    2625          18.6          82
# 397  31.0         4  119.0          82    2720          19.4          82
#
#      origin
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...

# %%
cor = auto1.corr()
cor
# Out:
#                    mpg  cylinder       dis  horsepower    weight  \
# mpg           1.000000 -0.775396 -0.804203   -0.753177 -0.831741
# cylinder     -0.775396  1.000000  0.950721    0.818454  0.896017
# dis          -0.804203  0.950721  1.000000    0.873330  0.932824
# horsepower   -0.753177  0.818454  0.873330    1.000000  0.841770
# weight       -0.831741  0.896017  0.932824    0.841770  1.000000
# acceleration  0.420289 -0.505419 -0.543684   -0.665833 -0.417457
# model_year    0.579267 -0.348746 -0.370164   -0.397772 -0.306564
# origin        0.563450 -0.562543 -0.609409   -0.454271 -0.581024
#
#               acceleration  model_year    origin
# mpg               0.420289    0.579267  0.563450
# cylinder         -0.505419   -0.348746 -0.562543
# dis              -0.543684   -0.370164 -0.609409
# horsepower       -0.665833   -0.397772 -0.454271
# weight           -0.417457   -0.306564 -0.581024
# acceleration      1.000000    0.288137  0.205873
# ...

# %%
plt.figure(figsize=(6,6))
sns.heatmap(cor,annot=True)
plt.show()
